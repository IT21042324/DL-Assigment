# %% [markdown]
# ### Import Libraries

# %%
import os
import pickle
import numpy as np
from tqdm import tqdm
import tensorflow.keras as K
from tensorflow.keras.preprocessing import image
from sklearn.model_selection import StratifiedShuffleSplit
from tensorflow.keras.preprocessing.image import img_to_array
import pandas as pd

# %%
import tensorflow as tf

# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
dataset_dir = 'acne_images/'

# Get the list of all entries in the directory
entries = os.listdir(dataset_dir)

# Filter out only the directories
folders = [entry for entry in entries if os.path.isdir(os.path.join(dataset_dir, entry))][1:]

print(folders)
# Out:
# ['cysts', 'nodules', 'papules', 'pustules']

# %% [markdown]
# # Data Preparation for Acne Types

# %% [markdown]
# ### 1. Conversion of Multi Class to Multi Label

# %%
multi_label_image_dir= 'acne_image_multi_label' 
os.makedirs(multi_label_image_dir, exist_ok=True)

# %%
# Define the labels as folder names
labels = ['comedones', 'cysts', 'nodules', 'papules', 'pustules']

# Create a dictionary to hold the image names and their associated label binary indicators
image_labels = {}

# Iterate over each label (folder)
for label in labels:
    folder_path = os.path.join(dataset_dir, label)
    
    # Check if the folder exists
    if not os.path.exists(folder_path):
        continue
    
    # Get the list of images in the current folder
    images = os.listdir(folder_path)
    
    # Iterate over each image
    for image in images:
        image_path = os.path.join(folder_path, image)
        
        # Ensure it's a file (and not a directory)
        if os.path.isfile(image_path):
            # If the image is already in the dictionary, update the current label to 1
            if image in image_labels:
                image_labels[image][label] = 1
            else:
                # Otherwise, create a new entry for the image with all labels initialized to 0
                image_labels[image] = {lbl: 0 for lbl in labels}
                image_labels[image][label] = 1

# Convert the dictionary into a DataFrame
image_labels_df = pd.DataFrame([
    {"image_name": image, **label_dict}
    for image, label_dict in image_labels.items()
])

# Save the DataFrame to a CSV file
output_csv_path = os.path.join(multi_label_image_dir, 'image_labels.csv')
image_labels_df.to_csv(output_csv_path, index=False)

print(f"CSV file created: {output_csv_path}")
# Out:
# CSV file created: acne_image_multi_label\image_labels.csv

# %% [markdown]
# ### Visualising Dataset Distribution for each label

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
csv_file_path = 'acne_image_multi_label/image_labels.csv'
image_labels_df = pd.read_csv(csv_file_path)

# Count the number of images for each label
label_counts = image_labels_df.iloc[:, 1:].sum()

# Print the counts to verify
print("Label Counts:\n", label_counts)
# Out:
# Label Counts:
#  comedones    294
# cysts        125
# nodules      140
# papules      341
# pustules     342
# dtype: int64
# C:\Users\imree\AppData\Roaming\Python\Python311\site-packages\matplotlib\projections\__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
# ### ` 1. Bar Plot `

# %%
# Bar Plot
plt.figure(figsize=(8, 6))
plt.bar(label_counts.index, label_counts.values, color='skyblue')
plt.xlabel('Acne Type')
plt.ylabel('Number of Images')
plt.title('Distribution of Images by Acne Type')
plt.xticks(rotation=45)
plt.tight_layout()  # Adjusts plot to ensure everything fits without overlapping
plt.show()

# %% [markdown]
# ### ` 2. Pie Chart`

# %%
# Pie Chart
plt.figure(figsize=(8, 8))  # Make the figure square for the pie chart

# Explode the largest slice a bit for emphasis
explode = (0.05, 0.05, 0.05, 0.05, 0.05)  # Exploding all slices slightly for more visibility

# Create the pie chart
plt.pie(
    label_counts.values, 
    labels=label_counts.index, 
    autopct='%1.1f%%', 
    startangle=140, 
    explode=explode,  # Add explode effect
    shadow=True,  # Add shadow for depth
    colors=plt.cm.Set3.colors,  # Use a more vibrant color palette
    textprops={'fontsize': 12},  # Increase the font size of the percentages
    wedgeprops={'linewidth': 2, 'edgecolor': 'white'}  # Make the edges more distinct
)

# Add a title with a larger font size
plt.title('Percentage of Images by Acne Type', fontsize=16)

# Add a legend to the side of the chart
plt.legend(label_counts.index, title="Acne Types", loc="best", bbox_to_anchor=(1, 0.5))

# Display the pie chart
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Image Augmentation to enhance Dataset

# %% [markdown]
# `Based on the observations, it is evident that the dataset is highly imbalanced, with the 'cysts' and 'nodules' classes having significantly fewer images compared to the other three acne types. To address this imbalance, images exclusively belonging to the 'cysts' and 'nodules' categories were selected and augmented using various transformations. This augmentation was done to increase the number of images in these two classes, ensuring a more balanced dataset across all acne types.`

# %%
augmentation_dir = 'augmented_images/'  # Directory for storing augmented images
os.makedirs(augmentation_dir, exist_ok=True)

# %%
import os
import pandas as pd
import numpy as np
from PIL import Image
import shutil  # To copy files
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define directories
dataset_dir = 'acne_images/'  # Original images folder
multi_image_labels_dir = 'acne_image_multi_label/'  # Combined images folder
augmentation_dir = 'augmented_images/'  # Directory for storing augmented images

# Ensure required directories exist
for dir_path in [multi_image_labels_dir, augmentation_dir]:
    if not os.path.exists(dir_path):
        os.makedirs(dir_path)
        print(f"Created directory: {dir_path}")

# Define the labels as folder names
labels = ['comedones', 'cysts', 'nodules', 'papules', 'pustules']

# Step 1: Copy all images to 'multi_image_labels' folder
def copy_all_images_to_multi_label(source_dirs, dest_dir):
    for source_dir in source_dirs:
        for file_name in os.listdir(source_dir):
            source_file_path = os.path.join(source_dir, file_name)
            if os.path.isfile(source_file_path):
                dest_file_path = os.path.join(dest_dir, file_name)
                shutil.copy(source_file_path, dest_file_path)
                print(f"Copied {file_name} to {dest_dir}")

# Copy images from original folders to 'multi_image_labels' folder
image_folders = [os.path.join(dataset_dir, label) for label in labels]
copy_all_images_to_multi_label(image_folders, multi_image_labels_dir)

# Step 2: Load CSV file and augment selected images
image_labels_df = pd.read_csv('acne_image_multi_label/image_labels.csv')

# Identify images exclusively belonging to 'nodules' or 'cysts'
nodules_images = image_labels_df[
    (image_labels_df['nodules'] == 1) & 
    (image_labels_df['cysts'] == 0) & 
    (image_labels_df['comedones'] == 0) & 
    (image_labels_df['papules'] == 0) & 
    (image_labels_df['pustules'] == 0)
]

cysts_images = image_labels_df[
    (image_labels_df['cysts'] == 1) & 
    (image_labels_df['nodules'] == 0) & 
    (image_labels_df['comedones'] == 0) & 
    (image_labels_df['papules'] == 0) & 
    (image_labels_df['pustules'] == 0)
]

# Calculate how many images to generate for balancing (set to 200 for both classes)
target_count = 200
nodules_to_augment = max(0, target_count - len(nodules_images))
cysts_to_augment = max(0, target_count - len(cysts_images))

print(f"Augmenting {nodules_to_augment} 'nodules' images and {cysts_to_augment} 'cysts' images.")

# ImageDataGenerator for augmentation
datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Step 2: Augment images
def augment_images(image_names, target_dir, count):
    augmented_images = []
    
    for image_name in image_names:
        image_path = os.path.join(multi_image_labels_dir, image_name)
        if not os.path.isfile(image_path):
            print(f"Image not found: {image_path}")
            continue
        
        image = Image.open(image_path).convert('RGB')
        image_array = np.array(image)

        # Create a batch of one image (required for ImageDataGenerator)
        image_array = np.expand_dims(image_array, axis=0)

        # Generate augmented images
        for i in range(count // len(image_names) + 1):
            augmented_iterator = datagen.flow(image_array, batch_size=1)

            # Generate one augmented image
            augmented_image = next(augmented_iterator)[0].astype(np.uint8)
            augmented_image = Image.fromarray(augmented_image)

            # Create a unique name for the augmented image
            augmented_image_name = f"{os.path.splitext(image_name)[0]}_aug_{i}.jpg"
            augmented_image_path = os.path.join(target_dir, augmented_image_name)

            # Save the augmented image
            augmented_image.save(augmented_image_path)

            # Add to list of augmented images
            augmented_images.append(augmented_image_name)

    # Return the names of the augmented images
    return augmented_images

# Augment 'nodules' and 'cysts' images
nodules_augmented_images = augment_images(nodules_images['image_name'], augmentation_dir, nodules_to_augment)
cysts_augmented_images = augment_images(cysts_images['image_name'], augmentation_dir, cysts_to_augment)

# Step 3: Prepare new labels for augmented images
def create_augmented_labels(image_names, label_index):
    new_labels = []
    for image_name in image_names:
        label_array = [0] * len(labels)
        label_array[label_index] = 1
        new_labels.append((image_name, *label_array))
    return new_labels

# Generate new label entries for augmented images
new_nodules_labels = create_augmented_labels(nodules_augmented_images, labels.index('nodules'))
new_cysts_labels = create_augmented_labels(cysts_augmented_images, labels.index('cysts'))

# Convert lists to DataFrame
augmented_labels_df = pd.DataFrame(new_nodules_labels + new_cysts_labels, columns=['image_name'] + labels)

# Step 3: Append the new entries to the original DataFrame
updated_image_labels_df = pd.concat([image_labels_df, augmented_labels_df])

# Save updated labels to CSV in the 'multi_image_labels' folder
updated_csv_file_path = os.path.join(multi_image_labels_dir, 'updated_image_labels.csv')
updated_image_labels_df.to_csv(updated_csv_file_path, index=False)

print(f"Updated image labels saved to: {updated_csv_file_path}")

# Step 4: Copy augmented images to 'multi_image_labels' folder
def copy_augmented_images_to_multi_label(source_dir, dest_dir):
    for file_name in os.listdir(source_dir):
        source_file_path = os.path.join(source_dir, file_name)
        if os.path.isfile(source_file_path):
            dest_file_path = os.path.join(dest_dir, file_name)
            shutil.copy(source_file_path, dest_file_path)
            print(f"Copied {file_name} to {dest_dir}")

# Copy augmented images from 'augmented_images' folder to 'multi_image_labels' folder
copy_augmented_images_to_multi_label(augmentation_dir, multi_image_labels_dir)

# Print summary
print(f"All augmented images copied to {multi_image_labels_dir}. Updated CSV: {updated_csv_file_path}")
# Out:
# Copied 2 (53).jpg to acne_image_multi_label/
# Copied 2 (53)1 - Copy.jpg to acne_image_multi_label/
# Copied 2 (53)1.jpg to acne_image_multi_label/
# Copied 34_jpeg_jpg.rf.0adac2e488226fb2f0f8b5758f839c62.jpg to acne_image_multi_label/
# Copied 34_jpeg_jpg.rf.49572e8927f4afe62232bf87651b9bbc.jpg to acne_image_multi_label/
# Copied 360_F_76033410_rJoKiNewoRuSzxXkALKr6bbYwl2U39Dk.jpg to acne_image_multi_label/
# Copied 360_F_85737201_RFt8QXLWzkiDVrKjUErqcoHliE9PAMHR.jpg to acne_image_multi_label/
# Copied Acne (143).jpg to acne_image_multi_label/
# Copied acne-black-spots-and-scars-on-forehead.jpg to acne_image_multi_label/
# Copied acne-closed-comedo-34.jpg to acne_image_multi_label/
# Copied acne-closed-comedo-38.jpg to acne_image_multi_label/
# Copied acne-cystic-11.jpg to acne_image_multi_label/
# Copied acne-cystic-13.jpg to acne_image_multi_label/
# Copied acne-open-comedo-1.jpg to acne_image_multi_label/
# Copied acne-open-comedo-14.jpg to acne_image_multi_label/
# Copied acne-open-comedo-15.jpg to acne_image_multi_label/
# Copied acne-open-comedo-16.jpg to acne_image_multi_label/
# Copied acne-open-comedo-2.jpg to acne_image_multi_label/
# Copied acne-open-comedo-21.jpg to acne_image_multi_label/
# Copied acne-open-comedo-22.jpg to acne_image_multi_label/
# Copied acne-open-comedo-23.jpg to acne_image_multi_label/
# Copied acne-open-comedo-24.jpg to acne_image_multi_label/
# Copied acne-open-comedo-32.jpg to acne_image_multi_label/
# Copied acne-open-comedo-33.jpg to acne_image_multi_label/
# Copied acne-open-comedo-34.jpg to acne_image_multi_label/
# Copied acne-open-comedo-40.jpg to acne_image_multi_label/
# Copied acne-open-comedo-43.jpg to acne_image_multi_label/
# Copied acne-open-comedo-5.jpg to acne_image_multi_label/
# Copied acne-open-comedo-50.jpg to acne_image_multi_label/
# Copied acne-open-comedo-51.jpg to acne_image_multi_label/
# Copied acne-open-comedo-53.jpg to acne_image_multi_label/
# Copied acne-open-comedo-58.jpg to acne_image_multi_label/
# Copied acne-open-comedo-61.jpg to acne_image_multi_label/
# Copied acne-open-comedo-63.jpg to acne_image_multi_label/
# Copied acne-open-comedo-64.jpg to acne_image_multi_label/
# Copied acne-open-comedo-66.jpg to acne_image_multi_label/
# Copied acne-open-comedo-68.jpg to acne_image_multi_label/
# Copied acne-open-comedo-69.jpg to acne_image_multi_label/
# Copied acne-open-comedo-70.jpg to acne_image_multi_label/
# Copied acne-open-comedo-71.jpg to acne_image_multi_label/
# Copied acne-open-comedo-72.jpg to acne_image_multi_label/
# Copied acne-pustular-10.jpg to acne_image_multi_label/
# Copied acne-pustular-13.jpg to acne_image_multi_label/
# Copied acne-pustular-14.jpg to acne_image_multi_label/
# Copied acne-pustular-35.jpg to acne_image_multi_label/
# Copied acne-pustular-46.jpg to acne_image_multi_label/
# Copied acne-pustular-48.jpg to acne_image_multi_label/
# Copied acne-pustular-49.jpg to acne_image_multi_label/
# Copied acne-pustular-54.jpg to acne_image_multi_label/
# Copied acne-pustular-59.jpg to acne_image_multi_label/
# Copied acne-pustular-6.jpg to acne_image_multi_label/
# Copied acne-pustular-65.jpg to acne_image_multi_label/
# Copied acne-pustular-8.jpg to acne_image_multi_label/
# Copied acne-pustular-9.jpg to acne_image_multi_label/
# Copied acne-scar-5.jpg to acne_image_multi_label/
# Copied acne4__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpg to acne_image_multi_label/
# Copied acne_0001_10731602084e470e78b7dfe-21.jpg to acne_image_multi_label/
# Copied acne_conglobata_--261-_jpg.rf.bb591bcd278f4631ff953179e3511bc7.jpg to acne_image_multi_label/
# Copied Acne_vulgaris_on_a_very_oily_skin.jpg to acne_image_multi_label/
# Copied blackheads-j-300x183.jpg to acne_image_multi_label/
# Copied blackheads-on-nose-closeup-260nw-1123444064.jpg to acne_image_multi_label/
# Copied blackheads-on-skin-closeup-260nw-1146837959.jpg to acne_image_multi_label/
# Copied blackhead_122_jpg.rf.bf1adab37da1a84134d60a034827d48c.jpg to acne_image_multi_label/
# Copied blackhead_202_jpg.rf.193791d6ed06a2e0f27e5d37f6aa2682.jpg to acne_image_multi_label/
# Copied blackhead_22_jpg.rf.8d66c35ee98b21693092e007511f1658.jpg to acne_image_multi_label/
# Copied blackhead_242_jpg.rf.16c7f756632874844f57d1852aff3a8b.jpg to acne_image_multi_label/
# Copied blackhead_266_jpg.rf.9670469a23447aeeea282d3e97829c85.jpg to acne_image_multi_label/
# Copied blackhead_270_jpg.rf.bfd47271b441aae60e5b6b9794b26389.jpg to acne_image_multi_label/
# Copied blackhead_546_jpg.rf.9dca30f5fd77408946670747f43fc2e0.jpg to acne_image_multi_label/
# Copied blackhead_548_jpg.rf.421194aae7a0c0617a6441950a472e81.jpg to acne_image_multi_label/
# Copied blackhead_554_jpg.rf.8a3fefe5d7d934336263d2950ac06ef6.jpg to acne_image_multi_label/
# Copied blackhead_602_jpg.rf.6775bbaa944d1a7cafb5d41b32d1ad6d.jpg to acne_image_multi_label/
# Copied blackhead_616_jpg.rf.ad86f18a7cfb831eeadc093251e6819c.jpg to acne_image_multi_label/
# Copied blackhead_70_jpg.rf.f9d78857fa68d7f3ab761e1eed798527.jpg to acne_image_multi_label/
# Copied blackhead_79_jpg.rf.1a441fc8fa89a8b17b1d416d46f6c5e7.jpg to acne_image_multi_label/
# Copied cdcc (12).jpg to acne_image_multi_label/
# Copied cdcc (13).jpg to acne_image_multi_label/
# Copied cdcc (16).jpg to acne_image_multi_label/
# Copied cdcc (23).jpg to acne_image_multi_label/
# Copied cdcc (27).jpg to acne_image_multi_label/
# Copied cdcc (28).jpg to acne_image_multi_label/
# Copied cdcc (30).jpg to acne_image_multi_label/
# Copied cdcc (32).jpg to acne_image_multi_label/
# Copied cdcc (35).jpg to acne_image_multi_label/
# Copied cdcc (38).jpg to acne_image_multi_label/
# Copied cdcc (4).jpg to acne_image_multi_label/
# Copied cdcc (46).jpg to acne_image_multi_label/
# Copied cdcc (47).jpg to acne_image_multi_label/
# Copied cdcc (5).jpg to acne_image_multi_label/
# Copied cdcc (6).jpg to acne_image_multi_label/
# Copied cdcc (71).jpg to acne_image_multi_label/
# Copied cdcc (72).jpg to acne_image_multi_label/
# Copied cdcc (75).jpg to acne_image_multi_label/
# Copied cdcc (79).jpg to acne_image_multi_label/
# Copied cdcc (80).jpg to acne_image_multi_label/
# Copied cdcc (9).jpg to acne_image_multi_label/
# Copied cdccdcd (314).jpg to acne_image_multi_label/
# Copied cdcddcd (101).jpg to acne_image_multi_label/
# Copied cdcddcd (104).jpg to acne_image_multi_label/
# Copied cdcddcd (105).jpg to acne_image_multi_label/
# Copied cdcddcd (125).jpg to acne_image_multi_label/
# Copied cdcddcd (126).jpg to acne_image_multi_label/
# Copied cdcddcd (127).jpg to acne_image_multi_label/
# Copied cdcddcd (128).jpg to acne_image_multi_label/
# Copied cdcddcd (129).jpg to acne_image_multi_label/
# Copied cdcddcd (133).jpg to acne_image_multi_label/
# Copied cdcddcd (142).jpg to acne_image_multi_label/
# Copied cdcddcd (172).jpg to acne_image_multi_label/
# Copied cdcddcd (173).jpg to acne_image_multi_label/
# Copied cdcddcd (192).jpg to acne_image_multi_label/
# Copied cdcddcd (193).jpg to acne_image_multi_label/
# Copied cdcddcd (194).jpg to acne_image_multi_label/
# Copied cdcddcd (197).jpg to acne_image_multi_label/
# Copied cdcddcd (199).jpg to acne_image_multi_label/
# Copied cdcddcd (200).jpg to acne_image_multi_label/
# Copied cdcddcd (202).jpg to acne_image_multi_label/
# Copied cdcddcd (217).jpg to acne_image_multi_label/
# Copied cdcddcd (221).jpg to acne_image_multi_label/
# Copied cdcddcd (230).jpg to acne_image_multi_label/
# Copied cdcddcd (235).jpg to acne_image_multi_label/
# Copied cdcddcd (239).jpg to acne_image_multi_label/
# Copied cdcddcd (241).jpg to acne_image_multi_label/
# Copied cdcddcd (244).jpg to acne_image_multi_label/
# Copied cdcddcd (246).jpg to acne_image_multi_label/
# Copied cdcddcd (288).jpg to acne_image_multi_label/
# Copied cdcddcd (289).jpg to acne_image_multi_label/
# Copied cdcddcd (291).jpg to acne_image_multi_label/
# Copied cdcddcd (292).jpg to acne_image_multi_label/
# Copied cdcddcd (293).jpg to acne_image_multi_label/
# Copied cdcddcd (324).jpg to acne_image_multi_label/
# Copied cdcddcd (325).jpg to acne_image_multi_label/
# Copied cdcddcd (327).jpg to acne_image_multi_label/
# Copied cdcddcd (328).jpg to acne_image_multi_label/
# Copied cdcddcd (337).jpg to acne_image_multi_label/
# Copied cdcddcd (86).jpg to acne_image_multi_label/
# Copied cdcddcd (87).jpg to acne_image_multi_label/
# Copied cdcddcd (88).jpg to acne_image_multi_label/
# Copied cdcddcd (89).jpg to acne_image_multi_label/
# Copied cdcddcd (94).jpg to acne_image_multi_label/
# Copied cdcddcd (95).jpg to acne_image_multi_label/
# Copied cdcddcd (97).jpg to acne_image_multi_label/
# Copied close-up-nodular-cystic-acne-skin-JGFHD6-transformed.jpeg to acne_image_multi_label/
# Copied de_Carvalho_Quiz.JPG.jpg to acne_image_multi_label/
# Copied eaf6877939cdcfb5675eb1950de61364.png to acne_image_multi_label/
# Copied fvfvvfvf (10).jpg to acne_image_multi_label/
# Copied fvfvvfvf (11).jpg to acne_image_multi_label/
# Copied fvfvvfvf (128).jpg to acne_image_multi_label/
# Copied fvfvvfvf (130).jpg to acne_image_multi_label/
# Copied fvfvvfvf (131).jpg to acne_image_multi_label/
# Copied fvfvvfvf (132).jpg to acne_image_multi_label/
# Copied fvfvvfvf (148).jpg to acne_image_multi_label/
# Copied fvfvvfvf (149).jpg to acne_image_multi_label/
# Copied fvfvvfvf (151).jpg to acne_image_multi_label/
# Copied fvfvvfvf (152).jpg to acne_image_multi_label/
# Copied fvfvvfvf (159).jpg to acne_image_multi_label/
# Copied fvfvvfvf (16).jpg to acne_image_multi_label/
# Copied fvfvvfvf (160).jpg to acne_image_multi_label/
# Copied fvfvvfvf (161).jpg to acne_image_multi_label/
# Copied fvfvvfvf (162).jpg to acne_image_multi_label/
# Copied fvfvvfvf (163).jpg to acne_image_multi_label/
# Copied fvfvvfvf (164).jpg to acne_image_multi_label/
# Copied fvfvvfvf (165).jpg to acne_image_multi_label/
# Copied fvfvvfvf (167).jpg to acne_image_multi_label/
# Copied fvfvvfvf (168).jpg to acne_image_multi_label/
# Copied fvfvvfvf (17).jpg to acne_image_multi_label/
# Copied fvfvvfvf (178).jpg to acne_image_multi_label/
# Copied fvfvvfvf (180).jpg to acne_image_multi_label/
# Copied fvfvvfvf (21).jpg to acne_image_multi_label/
# Copied fvfvvfvf (215).jpg to acne_image_multi_label/
# Copied fvfvvfvf (222).jpg to acne_image_multi_label/
# Copied fvfvvfvf (223).jpg to acne_image_multi_label/
# Copied fvfvvfvf (239).jpg to acne_image_multi_label/
# Copied fvfvvfvf (24).jpg to acne_image_multi_label/
# Copied fvfvvfvf (240).jpg to acne_image_multi_label/
# Copied fvfvvfvf (242).jpg to acne_image_multi_label/
# Copied fvfvvfvf (243).jpg to acne_image_multi_label/
# Copied fvfvvfvf (244).jpg to acne_image_multi_label/
# Copied fvfvvfvf (245).jpg to acne_image_multi_label/
# Copied fvfvvfvf (247).jpg to acne_image_multi_label/
# Copied fvfvvfvf (248).jpg to acne_image_multi_label/
# Copied fvfvvfvf (25).jpg to acne_image_multi_label/
# Copied fvfvvfvf (250).jpg to acne_image_multi_label/
# Copied fvfvvfvf (254).jpg to acne_image_multi_label/
# Copied fvfvvfvf (255).jpg to acne_image_multi_label/
# Copied fvfvvfvf (257).jpg to acne_image_multi_label/
# Copied fvfvvfvf (259).jpg to acne_image_multi_label/
# Copied fvfvvfvf (260).jpg to acne_image_multi_label/
# Copied fvfvvfvf (261).jpg to acne_image_multi_label/
# Copied fvfvvfvf (263).jpg to acne_image_multi_label/
# Copied fvfvvfvf (265).jpg to acne_image_multi_label/
# Copied fvfvvfvf (268).jpg to acne_image_multi_label/
# Copied fvfvvfvf (269).jpg to acne_image_multi_label/
# Copied fvfvvfvf (275).jpg to acne_image_multi_label/
# Copied fvfvvfvf (278).jpg to acne_image_multi_label/
# Copied fvfvvfvf (279).jpg to acne_image_multi_label/
# Copied fvfvvfvf (280).jpg to acne_image_multi_label/
# Copied fvfvvfvf (281).jpg to acne_image_multi_label/
# Copied fvfvvfvf (31).jpg to acne_image_multi_label/
# Copied fvfvvfvf (32).jpg to acne_image_multi_label/
# Copied fvfvvfvf (34).jpg to acne_image_multi_label/
# Copied fvfvvfvf (35).jpg to acne_image_multi_label/
# Copied fvfvvfvf (379).jpg to acne_image_multi_label/
# Copied fvfvvfvf (38).jpg to acne_image_multi_label/
# Copied fvfvvfvf (380).jpg to acne_image_multi_label/
# Copied fvfvvfvf (393).jpg to acne_image_multi_label/
# Copied fvfvvfvf (397).jpg to acne_image_multi_label/
# Copied fvfvvfvf (400).jpg to acne_image_multi_label/
# Copied fvfvvfvf (403).jpg to acne_image_multi_label/
# Copied fvfvvfvf (405).jpg to acne_image_multi_label/
# Copied fvfvvfvf (41).jpg to acne_image_multi_label/
# Copied fvfvvfvf (43).jpg to acne_image_multi_label/
# Copied fvfvvfvf (72).jpg to acne_image_multi_label/
# Copied fvfvvfvf (73).jpg to acne_image_multi_label/
# Copied fvfvvfvf (77).jpg to acne_image_multi_label/
# Copied fvfvvfvf (80).jpg to acne_image_multi_label/
# Copied fvfvvfvf (84).jpg to acne_image_multi_label/
# Copied fvfvvfvf (88).jpg to acne_image_multi_label/
# Copied fvfvvfvf (89).jpg to acne_image_multi_label/
# Copied fvfvvfvf (9).jpg to acne_image_multi_label/
# Copied How_to_Figure_Out_What_Type_of_Acne_You_Have_SLMD_f.jpg to acne_image_multi_label/
# Copied image10.jpeg to acne_image_multi_label/
# Copied image25.jpeg to acne_image_multi_label/
# Copied IMG_2078_JPG.rf.a280dfa990f0c6700e5600b83e1a84bf.jpg to acne_image_multi_label/
# Copied IMG_2079_JPG.rf.c23d27691d97548c46e9c377bfc8cfd1.jpg to acne_image_multi_label/
# Copied IMG_2080_JPG.rf.8c407135f2ecd20d82bc36364f583bb0.jpg to acne_image_multi_label/
# Copied IMG_2081_JPG.rf.40c98e361eac21f0bf144f73f215dc57.jpg to acne_image_multi_label/
# Copied IMG_2082_JPG.rf.4c37a0ff7b494ade854a45aec2273735.jpg to acne_image_multi_label/
# Copied IMG_2083_JPG.rf.ef15093bc674254558bc3788f8540a30.jpg to acne_image_multi_label/
# Copied IMG_2088_JPG.rf.6a93a7426fd6430139ca5dad612b577a.jpg to acne_image_multi_label/
# Copied IMG_2089_JPG.rf.9fb1c6d13110ccbb85b9f289e837baf2.jpg to acne_image_multi_label/
# Copied IMG_2090_JPG.rf.c91d83e0785fe303501f7dd665c74385.jpg to acne_image_multi_label/
# Copied IMG_2093_JPG.rf.79da6c5d40f42309ac6cf3c8377def07.jpg to acne_image_multi_label/
# Copied IMG_2095_JPG.rf.19b47ad0beebcdd40639149791a79187.jpg to acne_image_multi_label/
# Copied IMG_2099_JPG.rf.d5db03fdbb81fb7ef191991c8ddda083.jpg to acne_image_multi_label/
# Copied IMG_2100_JPG.rf.29d9c1f81021dc9de7913371b82552b4.jpg to acne_image_multi_label/
# Copied IMG_2101_JPG.rf.09818426370aa24b8a5be039a807e779.jpg to acne_image_multi_label/
# Copied IMG_2103_JPG.rf.84d4af942909457d519539ef32f56cc4.jpg to acne_image_multi_label/
# Copied IMG_2106_JPG.rf.3803917d6a45de95e74a7e6f54075848.jpg to acne_image_multi_label/
# Copied IMG_2107_JPG.rf.89058936c5b548de465f0b14f73ea2a3.jpg to acne_image_multi_label/
# Copied Screenshot_20240125_054248_YouTube_jpg.rf.807da56856c5a33a1dabf142b990a9c0.jpg to acne_image_multi_label/
# Copied Screenshot_3_jpg.rf.4053d373448fabd719bbb63570b727c7.jpg to acne_image_multi_label/
# Copied scscscs (50).jpg to acne_image_multi_label/
# Copied Types-of-Acne-Comodonal-Acne-Cystic-and-Nodular-Acne-Inflammatory-Acne.jpg to acne_image_multi_label/
# Copied Untitled-design--17-_11zon.jpg to acne_image_multi_label/
# Copied white_head_--11-_jpg.rf.1988f5faf5dd4ef32150ea0a0a688ba1.jpg to acne_image_multi_label/
# Copied white_head_--14-_jpg.rf.e7949140288dee52abaa5fb5749e25ca.jpg to acne_image_multi_label/
# Copied white_head_--15-_jpg.rf.afdf02151b8c9a0c6dd17c9ddd45333e.jpg to acne_image_multi_label/
# Copied white_head_--16-_jpg.rf.aaf34a81e8e15899fb504ff8561dbbe8.jpg to acne_image_multi_label/
# Copied white_head_--17-_jpg.rf.484a3c7ca909cda8af1369fdd2288326.jpg to acne_image_multi_label/
# Copied white_head_--4-_jpg.rf.2c5e1dc7d13bda782a640b74eae5e249.jpg to acne_image_multi_label/
# Copied white_head_--5-_jpg.rf.7037d111b21490977c6338b8970e8488.jpg to acne_image_multi_label/
# Copied white_head_--8-_jpg.rf.47e8f08ffcbce98c2bb1118dbdf0f7a8.jpg to acne_image_multi_label/
# Copied _10_11zon.jpg to acne_image_multi_label/
# Copied _11_11zon.jpg to acne_image_multi_label/
# Copied _16_11zon.jpg to acne_image_multi_label/
# Copied _1_11zon.jpg to acne_image_multi_label/
# Copied _20_11zon.jpg to acne_image_multi_label/
# Copied _22_11zon.jpg to acne_image_multi_label/
# Copied _27_11zon.jpg to acne_image_multi_label/
# Copied _32_11zon.jpg to acne_image_multi_label/
# Copied _37_11zon.jpg to acne_image_multi_label/
# Copied _38_11zon.jpg to acne_image_multi_label/
# Copied _39_11zon.jpg to acne_image_multi_label/
# Copied _48_11zon.jpg to acne_image_multi_label/
# Copied _52_11zon.jpg to acne_image_multi_label/
# Copied _6_11zon.jpg to acne_image_multi_label/
# Copied 1.png to acne_image_multi_label/
# Copied 11.jpeg to acne_image_multi_label/
# Copied 2 (3)1.jpg to acne_image_multi_label/
# Copied 2 (5).jpg to acne_image_multi_label/
# Copied 2 (5)1.jpg to acne_image_multi_label/
# Copied 2 (6).jpg to acne_image_multi_label/
# Copied 2 (6)1.jpg to acne_image_multi_label/
# Copied 2-Figure1-1.png to acne_image_multi_label/
# Copied 22_jpg.rf.684945b6131035df294f3abc63e884c9.jpg to acne_image_multi_label/
# Copied 2356.jpg to acne_image_multi_label/
# Copied 278_acne_slide_17_springer_high.jpg to acne_image_multi_label/
# Copied 3-_jpg.rf.afa61781f4e073c745ec0eb2deb6d4a5.jpg to acne_image_multi_label/
# Copied 32212176-8650569-image-a-10_1598002142635.jpg to acne_image_multi_label/
# Copied 32212176-8650569-image-a-10_15980021426351.jpg to acne_image_multi_label/
# Copied 32212176-8650569-image-a-10_159800214263511.jpg to acne_image_multi_label/
# Copied 32212176-8650569-image-a-10_1598002142635111 - Copy.jpg to acne_image_multi_label/
# Copied 32212176-8650569-image-a-10_1598002142635111.jpg to acne_image_multi_label/
# Copied 362f516bc2be4f01904fb2950eb700f4.png to acne_image_multi_label/
# Copied 362f516bc2be4f01904fb2950eb700f41.png to acne_image_multi_label/
# Copied 362f516bc2be4f01904fb2950eb700f411.png to acne_image_multi_label/
# Copied 48.jpg to acne_image_multi_label/
# Copied 53.jpg to acne_image_multi_label/
# Copied 54a279bcec5a872af278da1d9a9f7337--clear-skin-acne.jpg to acne_image_multi_label/
# Copied 54a279bcec5a872af278da1d9a9f7337--clear-skin-acne1 - Copy.jpg to acne_image_multi_label/
# Copied 54a279bcec5a872af278da1d9a9f7337--clear-skin-acne1.jpg to acne_image_multi_label/
# Copied 5b5029d077a7a1ae6d65404a15e07580.jpg to acne_image_multi_label/
# Copied a-photograph-of-inflammatory-or-mixed-acne-in-a-male-subject-showing-ARCRX6-transformed.jpeg to acne_image_multi_label/
# Copied abscess-or-nodular-acne-in-face-of-asian-burmese-male-patient-2GMFAH6.jpg to acne_image_multi_label/
# Copied Acne (30).jpg to acne_image_multi_label/
# Copied acne-and-skin-problem-2023-11-27-04-52-59-utc-min_600x.png to acne_image_multi_label/
# Copied acne-conglobata-1.jpg to acne_image_multi_label/
# Copied Acne-Conglobata.jpg to acne_image_multi_label/
# Copied Acne-cyst-1-150x150.jpg to acne_image_multi_label/
# Copied acne-cystic-143.jpg to acne_image_multi_label/
# Copied acne-cystic-145.jpg to acne_image_multi_label/
# Copied acne-cystic-29.jpg to acne_image_multi_label/
# Copied acne-cystic-31.jpg to acne_image_multi_label/
# Copied acne-cystic-34.jpg to acne_image_multi_label/
# Copied acne-cystic-42.jpg to acne_image_multi_label/
# Copied acne-cystic-86.jpg to acne_image_multi_label/
# Copied acne-cystic-93.jpg to acne_image_multi_label/
# Copied acne-pustular-21.jpg to acne_image_multi_label/
# Copied acne-pustular-22.jpg to acne_image_multi_label/
# Copied acne-pustular-28.jpg to acne_image_multi_label/
# Copied acne-pustular-62.jpg to acne_image_multi_label/
# Copied acne-pustulesandpapules-1593x2048.jpg to acne_image_multi_label/
# Copied acne-vulgaris-conglobata_jpg.rf.72acc8011bde081ea4bdda060551bddf.jpg to acne_image_multi_label/
# Copied acne5.png to acne_image_multi_label/
# Copied acneVulgaris_51059_lg.png to acne_image_multi_label/
# Copied acne_conglobata_--102-_jpg.rf.60cb9d2aab486cfd0db44eee43beefa7.jpg to acne_image_multi_label/
# Copied acne_conglobata_--106-_jpg.rf.77dad07a5a665a6e97d615607cbe57e1.jpg to acne_image_multi_label/
# Copied acne_conglobata_--162-_jpg.rf.4c7a6e3450b29fd02805e0e23ca20634.jpg to acne_image_multi_label/
# Copied acne_conglobata_--165-_jpg.rf.8231db29caa3843d9d2d2d0fbf17866d.jpg to acne_image_multi_label/
# Copied acne_conglobata_--256-_jpg.rf.17f6e278aba07d9cda4a4fdc911a5d4a.jpg to acne_image_multi_label/
# Copied acne_treatment_kaliterna1 - Copy.jpg to acne_image_multi_label/
# Copied acne_treatment_kaliterna1.jpg to acne_image_multi_label/
# Copied shutterstock_2223729759_jpg.rf.15d340497bb97e2603bd2a4155437986.jpg to acne_image_multi_label/
# Copied Thirteen ways to remove acne scars quickly in one day (1).jpg to acne_image_multi_label/
# Copied Thirteen ways to remove acne scars quickly in one day.jpg to acne_image_multi_label/
# Copied -1-_jpg.rf.2bd8af5504f723516886fcc977d4d0a1.jpg to acne_image_multi_label/
# Copied 01F3MMWFKMEV4ZTBMDTVCRNY93_jpeg_jpg.rf.2038b0620f1f2e767c3a3f285bfbf601.jpg to acne_image_multi_label/
# Copied 01F3MMX0Y73AE4AJRD3856H8QV_jpeg_jpg.rf.091b4ef28bd9ba168e83e70d7b353c3e.jpg to acne_image_multi_label/
# Copied 01F3MMX0Y73AE4AJRD3856H8QV_jpeg_jpg.rf.5a32c887b7dfd862a89efa057ce2b362.jpg to acne_image_multi_label/
# Copied 01F3MMXCBM9Y4W3GB8FVCD2W56_jpeg_jpg.rf.8c9c855dea4ba52297770320ffcb0bd0.jpg to acne_image_multi_label/
# Copied 0922Acne_vulgaris_HH.jpg to acne_image_multi_label/
# Copied 1.png to acne_image_multi_label/
# Copied 11.jpeg to acne_image_multi_label/
# Copied 1107CFP_DCAcne_Index.jpg to acne_image_multi_label/
# Copied 13_231222_jpg.rf.791186487b3d2b76210429ae816bda7f.jpg to acne_image_multi_label/
# Copied 2 (13).jpg to acne_image_multi_label/
# Copied 2 (13)11.jpg to acne_image_multi_label/
# Copied 2 (3)1.jpg to acne_image_multi_label/
# Copied 2 (7)1.jpg to acne_image_multi_label/
# Copied 205841.jpg to acne_image_multi_label/
# Copied 2058411.jpg to acne_image_multi_label/
# Copied 26_jpg.rf.3c478395195b1890002c49f16118c324.jpg to acne_image_multi_label/
# Copied 26_jpg.rf.839d89a7f871a2ec820267e748ac396b.jpg to acne_image_multi_label/
# Copied 3-_jpg.rf.18db285f0e66dd4ffcca65f768d30d04.jpg to acne_image_multi_label/
# Copied 3468-Nodular-acne-of-the-face-1296x728-slide2.jpg to acne_image_multi_label/
# Copied 362f516bc2be4f01904fb2950eb700f4.png to acne_image_multi_label/
# Copied 362f516bc2be4f01904fb2950eb700f41.png to acne_image_multi_label/
# Copied 362f516bc2be4f01904fb2950eb700f411.png to acne_image_multi_label/
# Copied 3_n3_acne_nodulaire.jpg to acne_image_multi_label/
# Copied 4-_png.rf.f52fff6d7fa54f49c73a6024ccfacc78.jpg to acne_image_multi_label/
# Copied 4869DD4600000578-0-image-a-8_15165645277221.jpg to acne_image_multi_label/
# Copied 5-_jpg.rf.f8be395ba2132f651a3f7be6dd88c193.jpg to acne_image_multi_label/
# Copied 53.jpg to acne_image_multi_label/
# Copied 54.jpg to acne_image_multi_label/
# Copied 83avy6u56eh21.jpg to acne_image_multi_label/
# Copied 83avy6u56eh211 - Copy.jpg to acne_image_multi_label/
# Copied 83avy6u56eh211.jpg to acne_image_multi_label/
# Copied Acne (112).jpg to acne_image_multi_label/
# Copied Acne (170).jpg to acne_image_multi_label/
# Copied Acne (65).jpg to acne_image_multi_label/
# Copied acne-and-skin-problem-2023-11-27-04-52-59-utc-min_600x.jpg to acne_image_multi_label/
# Copied acne-and-skin-problem-2023-11-27-04-52-59-utc-min_600x.png to acne_image_multi_label/
# Copied acne-conglobata-1.png to acne_image_multi_label/
# Copied acne-cystic-127.jpg to acne_image_multi_label/
# Copied acne-cystic-28.jpg to acne_image_multi_label/
# Copied Acne-Nodules-and-Cysts-Courtesy-of-Bethanee-Schlosser-MD-PhD.png to acne_image_multi_label/
# Copied acnebefore.jpg to acne_image_multi_label/
# Copied acneVulgaris_31938_lg.webp to acne_image_multi_label/
# Copied acne_conglobata_--11-_jpg.rf.b30d553d8673648db8d6ce2cffb9a3f3.jpg to acne_image_multi_label/
# Copied acne_conglobata_--16-_jpg.rf.c2d12f6c513c58f6787f83003319b741.jpg to acne_image_multi_label/
# Copied acne_conglobata_--9-_jpg.rf.faae48acb5dc5cdab8348654eb99397b.jpg to acne_image_multi_label/
# Copied AdobeStock_489641916_Resized.jpeg to acne_image_multi_label/
# Copied Adult_acne (1).png to acne_image_multi_label/
# Copied Adult_acne.png to acne_image_multi_label/
# Copied backgrounds-lesions-skin-caused-by-260nw-2255950517.jpg to acne_image_multi_label/
# Copied caaa (1).jpg to acne_image_multi_label/
# Copied caaa (18).jpg to acne_image_multi_label/
# Copied ccc (37).jpg to acne_image_multi_label/
# Copied cdccscsc (46).jpg to acne_image_multi_label/
# Copied cdscsdsc (85).jpg to acne_image_multi_label/
# Copied coj7k6re1f021.png to acne_image_multi_label/
# Copied crystalline_acne_--133-_jpg.rf.36b5d45d90cddddf5abb3245430025af.jpg to acne_image_multi_label/
# Copied crystalline_acne_--9-_jpg.rf.3f6dea1633ba5dbb296e0a3030bf4971.jpg to acne_image_multi_label/
# Copied csacac (45).jpg to acne_image_multi_label/
# Copied csacac (58).jpg to acne_image_multi_label/
# Copied cyst.png to acne_image_multi_label/
# Copied cystic-acne-chin-350x350.webp to acne_image_multi_label/
# Copied cystic_acne_--181-_jpg.rf.adc402926346ac6e94cdb8826e30719c.jpg to acne_image_multi_label/
# Copied cystic_acne_--181-_jpg.rf.fa911eac0466ba10ca807a8015325803.jpg to acne_image_multi_label/
# Copied cystic_acne_--25-_jpg.rf.a98c57818ebea1059989e0126148d8e6.jpg to acne_image_multi_label/
# Copied cystic_acne_--68-_jpg.rf.4c8ad4834275769763223a9d2fda8e57.jpg to acne_image_multi_label/
# Copied cystic_acne_--68-_jpg.rf.7f3ddca4e3f6e2dce72385992ea3d391.jpg to acne_image_multi_label/
# Copied cystic_acne_--84-_jpg.rf.5ee8b528ab9c57a46876f23273b0cb71.jpg to acne_image_multi_label/
# Copied cystic_acne_--84-_jpg.rf.ec883c1c4b1d10995c3339f13f67fda8.jpg to acne_image_multi_label/
# Copied cystic_acne_--91-_jpg.rf.20e155d9a0bb5241f23c334cdb9cda55.jpg to acne_image_multi_label/
# Copied cysts_copy_large.png to acne_image_multi_label/
# Copied desktop.ini to acne_image_multi_label/
# Copied F-DermatologyQuiz-107.jpg to acne_image_multi_label/
# Copied levle3_101_jpg.rf.55f5070e81f1020456b1efc34238a5d3.jpg to acne_image_multi_label/
# Copied levle3_102_jpg.rf.a330aa113b5f0ca4b863ae04db79903a.jpg to acne_image_multi_label/
# Copied levle3_104_jpg.rf.fcf4a5166a356e4504f71457a2bca653.jpg to acne_image_multi_label/
# Copied levle3_130_jpg.rf.ebec30a39f0b0840db9f71963bd6514a.jpg to acne_image_multi_label/
# Copied levle3_133_png_jpg.rf.ad347f54864af045e80770e8128a8f15.jpg to acne_image_multi_label/
# Copied levle3_49_jpg.rf.091dce295dc068c873eef80257330b16.jpg to acne_image_multi_label/
# Copied mixUp.jpeg to acne_image_multi_label/
# Copied nodular-acne (1).jpg to acne_image_multi_label/
# Copied Nodular-Acne.jpg to acne_image_multi_label/
# Copied Nodular_Acne_Face_Symptoms_Papules_Pustules_Cysts.png to acne_image_multi_label/
# Copied Nodular_Acne_Face_Symptoms_Papules_Pustules_Cysts_result.png to acne_image_multi_label/
# Copied pexels-anthony-shkraba-5881800.jpg to acne_image_multi_label/
# Copied pigmentation_0_1083.jpeg to acne_image_multi_label/
# Copied pigmentation_0_6919.jpeg to acne_image_multi_label/
# Copied pustular_acne_--86-_jpg.rf.4bcfc5c5bedaafaa10d942397ab3e152.jpg to acne_image_multi_label/
# Copied q (42).jpg to acne_image_multi_label/
# Copied R (28).jpg to acne_image_multi_label/
# Copied R (3).jpg to acne_image_multi_label/
# Copied R (42).jpg to acne_image_multi_label/
# Copied Screenshot_20240121_194956_Google_jpg.rf.a7b2fdae66e760b75254fd8cc0901987.jpg to acne_image_multi_label/
# Copied Screenshot_20240121_195105_Google_jpg.rf.bae092e0979ba69907522cf1ae201d41.jpg to acne_image_multi_label/
# Copied set2---138-_jpg.rf.043dfd8e5633aacb783c5f1a6f7468e7.jpg to acne_image_multi_label/
# Copied set2---143-_jpg.rf.e3c8413ef3334016b0cc2ca15a76dd55.jpg to acne_image_multi_label/
# Copied set2---181-_jpg.rf.b8d947c99f9b5a5dcc536c888cf5b4b6.jpg to acne_image_multi_label/
# Copied set2---202-_jpg.rf.2be8f6f6f74cf7ee9a32dff36e78fce3.jpg to acne_image_multi_label/
# Copied set2---247-_jpg.rf.e6c133e708ff1e26cd6f2e4c7c16d272.jpg to acne_image_multi_label/
# Copied set2---256-_jpg.rf.cffa3f4c0fc572fbfd7675d02a8df75a.jpg to acne_image_multi_label/
# Copied set2---293-_jpg.rf.51f8184778efcf4d7369a0e20c81a931.jpg to acne_image_multi_label/
# Copied Untitled_design_24.png to acne_image_multi_label/
# Copied xxx x (9).jpg to acne_image_multi_label/
# Copied young-caucasian-woman-suffering-from-rosacea-on-her-face-in-the-acute-stage-dermatological.jpg to acne_image_multi_label/
# Copied 01F3MMWASQXMT2JDT81P87MS6M_jpeg_jpg.rf.2a683222ebf5b8b2af130d2924919527.jpg to acne_image_multi_label/
# Copied 047_acne_01_-_resized-min_1_480x480.jpg to acne_image_multi_label/
# Copied 07Acne081101.jpg to acne_image_multi_label/
# Copied 07Acne0811011 - Copy.jpg to acne_image_multi_label/
# Copied 07Acne0811011.jpg to acne_image_multi_label/
# Copied 0922Acne_vulgaris_HH.jpg to acne_image_multi_label/
# Copied 0_19hJvhBaJyf8eJwT_.jpg to acne_image_multi_label/
# Copied 10.jpg to acne_image_multi_label/
# Copied 1107CFP_DCAcne_Index.jpg to acne_image_multi_label/
# Copied 111.jpg to acne_image_multi_label/
# Copied 11118622-6820319-image-a-24_15528711043151.jpg to acne_image_multi_label/
# Copied 13.jpg to acne_image_multi_label/
# Copied 16.jpg to acne_image_multi_label/
# Copied 17.jpg to acne_image_multi_label/
# Copied 17a4d1a917e5faa9f2675ebd83e52679.jpg to acne_image_multi_label/
# Copied 17a4d1a917e5faa9f2675ebd83e526791 - Copy.jpg to acne_image_multi_label/
# Copied 17a4d1a917e5faa9f2675ebd83e526791.jpg to acne_image_multi_label/
# Copied 19280a95363d065b1dfbc654e2853029.jpg to acne_image_multi_label/
# Copied 19280a95363d065b1dfbc654e28530291 - Copy.jpg to acne_image_multi_label/
# Copied 19280a95363d065b1dfbc654e28530291.jpg to acne_image_multi_label/
# Copied 2 (12).jpeg to acne_image_multi_label/
# Copied 2 (12)1.jpeg to acne_image_multi_label/
# Copied 2 (12)11.jpeg to acne_image_multi_label/
# Copied 2 (2).jpg to acne_image_multi_label/
# Copied 2 (2)1.jpg to acne_image_multi_label/
# Copied 2 (3).jpeg to acne_image_multi_label/
# Copied 2 (3)1.jpeg to acne_image_multi_label/
# Copied 2 (4)1.jpg to acne_image_multi_label/
# Copied 2 (51).jpg to acne_image_multi_label/
# Copied 2 (52).jpg to acne_image_multi_label/
# Copied 2 (52)1 - Copy.jpg to acne_image_multi_label/
# Copied 2 (52)1.jpg to acne_image_multi_label/
# Copied 2 (7).jpeg to acne_image_multi_label/
# Copied 2 (8).jpeg to acne_image_multi_label/
# Copied 2 1(1)1 - Copy.jpg to acne_image_multi_label/
# Copied 2 1(1)1.jpg to acne_image_multi_label/
# Copied 2.png to acne_image_multi_label/
# Copied 20150721042601_primary.jpg to acne_image_multi_label/
# Copied 20150721042601_primary1 - Copy.jpg to acne_image_multi_label/
# Copied 20150721042601_primary1.jpg to acne_image_multi_label/
# Copied 20181225_191537.jpg.923b0605b45be754fbbed9051a9bea5e1 - Copy.jpg to acne_image_multi_label/
# Copied 20181225_191537.jpg.923b0605b45be754fbbed9051a9bea5e1.jpg to acne_image_multi_label/
# Copied 205841.jpg to acne_image_multi_label/
# Copied 2058411.jpg to acne_image_multi_label/
# Copied 21.png to acne_image_multi_label/
# Copied 2327210.jpg to acne_image_multi_label/
# Copied 23272101.jpg to acne_image_multi_label/
# Copied 2356.jpg to acne_image_multi_label/
# Copied 27.jpg to acne_image_multi_label/
# Copied 28.png to acne_image_multi_label/
# Copied 31.jpg to acne_image_multi_label/
# Copied 32212176-8650569-image-a-10_1598002142635.jpg to acne_image_multi_label/
# Copied 32212176-8650569-image-a-10_15980021426351.jpg to acne_image_multi_label/
# Copied 32212176-8650569-image-a-10_159800214263511.jpg to acne_image_multi_label/
# Copied 32212176-8650569-image-a-10_1598002142635111 - Copy.jpg to acne_image_multi_label/
# Copied 32212176-8650569-image-a-10_1598002142635111.jpg to acne_image_multi_label/
# Copied 353492fd44963e8f0f4e7ea4697aed7e1.jpg to acne_image_multi_label/
# Copied 3_n3_acne_nodulaire.jpg to acne_image_multi_label/
# Copied 4.jpg to acne_image_multi_label/
# Copied 40_19hJvhBaJyf8eJwT_.jpg to acne_image_multi_label/
# Copied 4755A9F700000578-5179985-Desperate_attempts_to_rid_herself_of_the_unsightly_pimples_have_-a-55_1513271096522.jpg to acne_image_multi_label/
# Copied 4869DD4600000578-0-image-a-8_15165645277221.jpg to acne_image_multi_label/
# Copied 4A5DA7F500000578-5522003-Amy_who_battled_her_erupting_skin_for_15_years_says_doctors_dism-a-26_1521541958104.jpg to acne_image_multi_label/
# Copied 4A5DA7F500000578-5522003-Amy_who_battled_her_erupting_skin_for_15_years_says_doctors_dism-a-26_15215419581041 - Copy.jpg to acne_image_multi_label/
# Copied 4A5DA7F500000578-5522003-Amy_who_battled_her_erupting_skin_for_15_years_says_doctors_dism-a-26_15215419581041.jpg to acne_image_multi_label/
# Copied 5.jpg to acne_image_multi_label/
# Copied 54.jpg to acne_image_multi_label/
# Copied 7.jpg to acne_image_multi_label/
# Copied 752kd5y464t01.jpg to acne_image_multi_label/
# Copied 752kd5y464t011 - Copy.jpg to acne_image_multi_label/
# Copied 752kd5y464t011.jpg to acne_image_multi_label/
# Copied 766x415_Accutane_Side_Effects.jpg to acne_image_multi_label/
# Copied 7b5781acbf8cf3ef59928bf1fd56df9eC!r23ac1983a0274adecccb505518971ace.jpg to acne_image_multi_label/
# Copied 7b5781acbf8cf3ef59928bf1fd56df9eC!r23ac1983a0274adecccb505518971ace1.jpg to acne_image_multi_label/
# Copied 83avy6u56eh21.jpg to acne_image_multi_label/
# Copied 83avy6u56eh211 - Copy.jpg to acne_image_multi_label/
# Copied 83avy6u56eh211.jpg to acne_image_multi_label/
# Copied a4adb9e50d8636f5ec9ce65269dd92f7.jpg to acne_image_multi_label/
# Copied Acne (143).jpg to acne_image_multi_label/
# Copied Acne (190).jpg to acne_image_multi_label/
# Copied Acne (40).jpg to acne_image_multi_label/
# Copied Acne (42).jpg to acne_image_multi_label/
# Copied Acne (65).jpg to acne_image_multi_label/
# Copied Acne-006-300x180.jpg to acne_image_multi_label/
# Copied acne-1.jpg to acne_image_multi_label/
# Copied acne-and-skin-problem-2023-11-27-04-52-59-utc-min_600x.jpg to acne_image_multi_label/
# Copied Acne-Before4.png to acne_image_multi_label/
# Copied Acne-Before41.png to acne_image_multi_label/
# Copied acne-black-spots-and-scars-oily-on-face2.jpg to acne_image_multi_label/
# Copied acne-breakout-GettyImages-11679106231 - Copy.jpg to acne_image_multi_label/
# Copied acne-breakout-GettyImages-11679106231.jpg to acne_image_multi_label/
# Copied acne-breakout-GettyImages-116791062311 - Copy.jpg to acne_image_multi_label/
# Copied acne-cystic-143.jpg to acne_image_multi_label/
# Copied acne-cystic-21.jpg to acne_image_multi_label/
# Copied acne-cystic-57.jpg to acne_image_multi_label/
# Copied acne-face_f_500x250.jpg to acne_image_multi_label/
# Copied acne-papules-pustules-pv-sized.jpg to acne_image_multi_label/
# Copied acne-pustular-24.jpg to acne_image_multi_label/
# Copied acne-pustular-25.jpg to acne_image_multi_label/
# Copied acne-pustular-27.jpg to acne_image_multi_label/
# Copied acne-pustular-29.jpg to acne_image_multi_label/
# Copied acne-pustular-31.jpg to acne_image_multi_label/
# Copied acne-pustular-35.jpg to acne_image_multi_label/
# Copied acne-pustular-37.jpg to acne_image_multi_label/
# Copied acne-pustular-40.jpg to acne_image_multi_label/
# Copied acne-pustular-42.jpg to acne_image_multi_label/
# Copied acne-pustular-57.jpg to acne_image_multi_label/
# Copied acne-pustular-62.jpg to acne_image_multi_label/
# Copied acne-pustular-7.jpg to acne_image_multi_label/
# Copied acne-scar-2.jpg to acne_image_multi_label/
# Copied acne-scar-3.jpg to acne_image_multi_label/
# Copied acne-scar-4.jpg to acne_image_multi_label/
# Copied acne-scar-rfmicroneedling-smoothbeam-vbeam-4500-18yo-caucasian-female-obliqueview2-after-6treatments-new-jersey.png to acne_image_multi_label/
# Copied acne-treatment-1024x1024.png to acne_image_multi_label/
# Copied acne-virginia.jpg to acne_image_multi_label/
# Copied acne-vulgaris-and-black-spots-over-whole-face-of-asian-woman-acne-occurs-when-hair-follicles.jpg to acne_image_multi_label/
# Copied acne-vulgaris-and-scars-over-whole-face-of-asian-woman-acne-occurs-when-hair-follicles-become.jpg to acne_image_multi_label/
# Copied acne.jpeg to acne_image_multi_label/
# Copied acne1.jpg to acne_image_multi_label/
# Copied acne5.png to acne_image_multi_label/
# Copied acnebefore.jpg to acne_image_multi_label/
# Copied AcneHeader.jpg to acne_image_multi_label/
# Copied acneVulgaris_31938_lg.webp to acne_image_multi_label/
# Copied acneVulgaris_51059_lg.png to acne_image_multi_label/
# Copied acne_0001_10731602084e470e78b7dfe-21.jpg to acne_image_multi_label/
# Copied acne_conglobata_--10-_jpg.rf.32724556f0c902cfceb06bdfbd959453.jpg to acne_image_multi_label/
# Copied acne_conglobata_--109-_jpg.rf.781bc067c144ba652cf6b1bc02e59ec7.jpg to acne_image_multi_label/
# Copied acne_conglobata_--162-_jpg.rf.4c7a6e3450b29fd02805e0e23ca20634.jpg to acne_image_multi_label/
# Copied acne_conglobata_--261-_jpg.rf.bb591bcd278f4631ff953179e3511bc7.jpg to acne_image_multi_label/
# Copied acne_conglobata_--58-_jpg.rf.7a570a352c65a38e28c5c93bc7d112da.jpg to acne_image_multi_label/
# Copied acne_conglobata_--85-_jpg.rf.48971ac52491978025860601fe6c18cf.jpg to acne_image_multi_label/
# Copied acne_conglobata_--92-_jpg.rf.24147a7da8f770e0fc177e4ffca2e346.jpg to acne_image_multi_label/
# Copied acne_study.jpeg to acne_image_multi_label/
# Copied acne_treatment1 - Copy.png to acne_image_multi_label/
# Copied acne_treatment1.png to acne_image_multi_label/
# Copied acne_vulgaris.png to acne_image_multi_label/
# Copied acne_vulgaris1.jpg to acne_image_multi_label/
# Copied Adult_acne (1).png to acne_image_multi_label/
# Copied fig1_aug_1.jpg to acne_image_multi_label/
# Copied fig1_aug_2.jpg to acne_image_multi_label/
# Copied fig1_aug_3.jpg to acne_image_multi_label/
# Copied Foliculitis_--356-_jpg.rf.667448581f05fc18027af8ed74ef5f58_aug_0.jpg to acne_image_multi_label/
# Copied Foliculitis_--356-_jpg.rf.667448581f05fc18027af8ed74ef5f58_aug_1.jpg to acne_image_multi_label/
# Copied Foliculitis_--356-_jpg.rf.667448581f05fc18027af8ed74ef5f58_aug_2.jpg to acne_image_multi_label/
# Copied Foliculitis_--356-_jpg.rf.667448581f05fc18027af8ed74ef5f58_aug_3.jpg to acne_image_multi_label/
# Copied hqdefault_aug_0.jpg to acne_image_multi_label/
# Copied hqdefault_aug_1.jpg to acne_image_multi_label/
# Copied hqdefault_aug_2.jpg to acne_image_multi_label/
# Copied images (1)_aug_0.jpg to acne_image_multi_label/
# Copied images (1)_aug_1.jpg to acne_image_multi_label/
# Copied images (1)_aug_2.jpg to acne_image_multi_label/
# Copied images (1)_aug_3.jpg to acne_image_multi_label/
# Copied images26_aug_0.jpg to acne_image_multi_label/
# Copied images26_aug_1.jpg to acne_image_multi_label/
# Copied images26_aug_2.jpg to acne_image_multi_label/
# Copied images59_aug_0.jpg to acne_image_multi_label/
# Copied images59_aug_1.jpg to acne_image_multi_label/
# Copied images59_aug_2.jpg to acne_image_multi_label/
# Copied images61_aug_0.jpg to acne_image_multi_label/
# Copied images61_aug_1.jpg to acne_image_multi_label/
# Copied images61_aug_2.jpg to acne_image_multi_label/
# Copied images69_aug_0.jpg to acne_image_multi_label/
# Copied images69_aug_1.jpg to acne_image_multi_label/
# Copied images69_aug_2.jpg to acne_image_multi_label/
# Copied images69_aug_3.jpg to acne_image_multi_label/
# Copied images_aug_0.jpg to acne_image_multi_label/
# Copied images_aug_1.jpg to acne_image_multi_label/
# Copied images_aug_2.jpg to acne_image_multi_label/
# Copied IYS8yKs_aug_0.jpg to acne_image_multi_label/
# Copied IYS8yKs_aug_1.jpg to acne_image_multi_label/
# Copied IYS8yKs_aug_2.jpg to acne_image_multi_label/
# Copied levle0_215_jpg.rf.e3e89de07d38ab1e670ed1e36fb94438_aug_0.jpg to acne_image_multi_label/
# Copied levle0_215_jpg.rf.e3e89de07d38ab1e670ed1e36fb94438_aug_1.jpg to acne_image_multi_label/
# Copied levle0_215_jpg.rf.e3e89de07d38ab1e670ed1e36fb94438_aug_2.jpg to acne_image_multi_label/
# Copied levle0_529_png_jpg.rf.fd1f39a67599509cc7a6aadae682b37a_aug_0.jpg to acne_image_multi_label/
# Copied levle0_529_png_jpg.rf.fd1f39a67599509cc7a6aadae682b37a_aug_1.jpg to acne_image_multi_label/
# Copied levle0_529_png_jpg.rf.fd1f39a67599509cc7a6aadae682b37a_aug_2.jpg to acne_image_multi_label/
# Copied levle1_189_png_jpg.rf.5d0ef407fc110f2e85c6eb7f15ed9224_aug_0.jpg to acne_image_multi_label/
# Copied levle1_189_png_jpg.rf.5d0ef407fc110f2e85c6eb7f15ed9224_aug_1.jpg to acne_image_multi_label/
# Copied set2---30-_jpg.rf.fc8d373d20fba5997ee498e598728134_aug_0.jpg to acne_image_multi_label/
# Copied set2---30-_jpg.rf.fc8d373d20fba5997ee498e598728134_aug_1.jpg to acne_image_multi_label/
# Copied set2---30-_jpg.rf.fc8d373d20fba5997ee498e598728134_aug_2.jpg to acne_image_multi_label/
# Copied set2---30-_jpg.rf.fc8d373d20fba5997ee498e598728134_aug_3.jpg to acne_image_multi_label/
# Copied shutterstock_2223729759_jpg.rf.15d340497bb97e2603bd2a4155437986_aug_0.jpg to acne_image_multi_label/
# Copied shutterstock_2223729759_jpg.rf.15d340497bb97e2603bd2a4155437986_aug_1.jpg to acne_image_multi_label/
# Copied shutterstock_2223729759_jpg.rf.15d340497bb97e2603bd2a4155437986_aug_2.jpg to acne_image_multi_label/
# Copied shutterstock_2223729759_jpg.rf.15d340497bb97e2603bd2a4155437986_aug_3.jpg to acne_image_multi_label/
# Copied xxx x (9)_aug_0.jpg to acne_image_multi_label/
# Copied xxx x (9)_aug_1.jpg to acne_image_multi_label/
# Copied xxx x (9)_aug_2.jpg to acne_image_multi_label/
# All augmented images copied to acne_image_multi_label/. Updated CSV: acne_image_multi_label/updated_image_labels.csv

# %% [markdown]
# ### Augmented Data Visualization

# %% [markdown]
# ### ` 1. Bar Plot `

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
csv_file_path = 'acne_image_multi_label/updated_image_labels.csv'
updated_image_labels_df = pd.read_csv(csv_file_path)

# Count the number of images for each label
label_counts = updated_image_labels_df.iloc[:, 1:].sum()

# Print the counts to verify
print("Label Counts:\n", label_counts)

# Bar Plot
plt.figure(figsize=(8, 6))
plt.bar(label_counts.index, label_counts.values, color='skyblue')
plt.xlabel('Acne Type')
plt.ylabel('Number of Images')
plt.title('Distribution of Images by Acne Type')
plt.xticks(rotation=45)
plt.tight_layout()  # Adjusts plot to ensure everything fits without overlapping
plt.show()
# Out:
# Label Counts:
#  comedones    294
# cysts        309
# nodules      311
# papules      341
# pustules     342
# dtype: int64

# %% [markdown]
# ### ` 2. Pie Chart `

# %%
# Pie Chart
plt.figure(figsize=(8, 8))
plt.pie(label_counts.values, labels=label_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Percentage of Images by Acne Type')
plt.show()

targets = np.array(image_labels_df.iloc[:, 1:])

# %%
updated_image_labels_df.shape
# Out:
# (1305, 6)

# %%
import pandas as pd
from skmultilearn.model_selection import iterative_train_test_split
import numpy as np
import os

# Load the updated CSV file with augmented images
dataset_dir = 'acne_image_multi_label/'
updated_csv_file_path = os.path.join(dataset_dir, 'updated_image_labels.csv')
updated_image_labels_df = pd.read_csv(updated_csv_file_path)

# Extract features and multilabel targets
X = updated_image_labels_df.drop(columns=['comedones', 'cysts', 'nodules', 'papules', 'pustules']).values
y = updated_image_labels_df[['comedones', 'cysts', 'nodules', 'papules', 'pustules']].values

# Perform iterative stratified split for multilabel data
X_train, y_train, X_temp, y_temp = iterative_train_test_split(X, y, test_size=0.2)
X_val, y_val, X_test, y_test = iterative_train_test_split(X_temp, y_temp, test_size=0.5)

# Convert arrays back to DataFrames
train_df = pd.DataFrame(np.hstack((X_train, y_train)), columns=updated_image_labels_df.columns)
val_df = pd.DataFrame(np.hstack((X_val, y_val)), columns=updated_image_labels_df.columns)
test_df = pd.DataFrame(np.hstack((X_test, y_test)), columns=updated_image_labels_df.columns)

# Save the splits into separate CSV files
train_csv_path = os.path.join(dataset_dir, 'train_image_labels.csv')
val_csv_path = os.path.join(dataset_dir, 'val_image_labels.csv')
test_csv_path = os.path.join(dataset_dir, 'test_image_labels.csv')

train_df.to_csv(train_csv_path, index=False)
val_df.to_csv(val_csv_path, index=False)
test_df.to_csv(test_csv_path, index=False)

# Print summary
print(f"Train set size: {len(train_df)}")
print(f"Validation set size: {len(val_df)}")
print(f"Test set size: {len(test_df)}")
# Out:
# Train set size: 1040
# Validation set size: 130
# Test set size: 135

# %%
train_df
# Out:
#                                              image_name comedones cysts  \
# 0                                    2 (53)1 - Copy.jpg         1     0
# 1     34_jpeg_jpg.rf.0adac2e488226fb2f0f8b5758f839c6...         1     0
# 2     360_F_76033410_rJoKiNewoRuSzxXkALKr6bbYwl2U39D...         1     0
# 3                                        Acne (143).jpg         1     0
# 4            acne-black-spots-and-scars-on-forehead.jpg         1     0
# ...                                                 ...       ...   ...
# 1035  set2---30-_jpg.rf.fc8d373d20fba5997ee498e59872...         0     1
# 1036  shutterstock_2223729759_jpg.rf.15d340497bb97e2...         0     1
# 1037  shutterstock_2223729759_jpg.rf.15d340497bb97e2...         0     1
# 1038  shutterstock_2223729759_jpg.rf.15d340497bb97e2...         0     1
# 1039  shutterstock_2223729759_jpg.rf.15d340497bb97e2...         0     1
#
#      nodules papules pustules
# 0          0       0        0
# 1          0       0        0
# 2          0       0        0
# 3          0       1        0
# 4          0       0        0
# ...      ...     ...      ...
# 1035       0       0        0
# 1036       0       0        0
# 1037       0       0        0
# 1038       0       0        0
# 1039       0       0        0
#
# [1040 rows x 6 columns]

# %% [markdown]
# ### Visualizing train dataset split

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
train_file_path = 'acne_image_multi_label/train_image_labels.csv'
train_image_labels_df = pd.read_csv(train_file_path)

# Count the number of images for each label
label_counts = train_image_labels_df.iloc[:, 1:].sum()

# Print the counts to verify
print("Label Counts:\n", label_counts)

# Bar Plot
plt.figure(figsize=(8, 6))
plt.bar(label_counts.index, label_counts.values, color='skyblue')
plt.xlabel('Acne Type')
plt.ylabel('Number of Images')
plt.title('Distribution of Images by Acne Type')
plt.xticks(rotation=45)
plt.tight_layout()  # Adjusts plot to ensure everything fits without overlapping
plt.show()

# Pie Chart
plt.figure(figsize=(8, 8))
plt.pie(label_counts.values, labels=label_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Percentage of Images by Acne Type')
plt.show()

targets = np.array(image_labels_df.iloc[:, 1:])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 6
#       4 # Load the CSV file
#       5 train_file_path = '../acne_image_multi_label/train_image_labels.csv'
# ----> 6 train_image_labels_df = pd.read_csv(train_file_path)
#       8 # Count the number of images for each label
#       9 label_counts = train_image_labels_df.iloc[:, 1:].sum()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../acne_image_multi_label/train_image_labels.csv'
